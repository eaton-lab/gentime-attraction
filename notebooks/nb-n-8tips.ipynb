# %% [markdown]
# ## Generation-time branch attraction
#
# This notebook focuses on (g) effects

# %%
# conda install ipcoal ipyrad -c conda-forge -c bioconda

# %%
import numpy as np
import pandas as pd
import toytree
import toyplot, toyplot.svg
import ipcoal
import ipyrad.analysis as ipa

# %% [markdown]
# ### Treestyle

# %%
ts = {
    'ts': 'p', 
    'layout': 'r',
    'height': 300,
    'node_sizes': 7,
    'node_style': {"stroke": "black", 'stroke-width': 2},
    'node_labels': False,
    'edge_type': 'c',
    'scalebar': False,
    'tip_labels_align': True,
    'scalebar': True,
}

# %% [markdown]
# ### Starting simulation scenario with deep divergences

# %%
# get an ultrametric imbalanced tree
tree = toytree.rtree.imbtree(8, treeheight=20e6)
tree.draw(**ts);
# Out:
# <div class="toyplot" id="t9b8b6149d4a74c5f8f67f4d61a189c3a" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="tbcc04b4783ed48b2b63774e04ee6f680" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 300.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tadf2d392318f48b5b9c634adfd62e83a"><clipPath id="t89432f8bff23421da3b28def05ae9216"><rect height="240.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t89432f8bff23421da3b28def05ae9216)"><g class="toytree-mark-Toytree" id="t2e0bf14d58d64d72a2d41395341f6f2f"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 56.0 86.4 L 75.7 111.5" id="14,13"></path><path d="M 75.7 111.5 L 95.4 136.5" id="13,12"></path><path d="M 95.4 136.5 L 115.1 161.1" id="12,11"></path><path d="M 115.1 161.1 L 134.8 184.9" id="11,10"></path><path d="M 134.8 184.9 L 154.5 207.1" id="10,9"></path><path d="M 154.5 207.1 L 174.2 226.1" id="9,8"></path><path d="M 56.0 86.4 L 193.9 61.2" id="14,7"></path><path d="M 75.7 111.5 L 193.9 86.6" id="13,6"></path><path d="M 95.4 136.5 L 193.9 111.9" id="12,5"></path><path d="M 115.1 161.1 L 193.9 137.3" id="11,4"></path><path d="M 134.8 184.9 L 193.9 162.7" id="10,3"></path><path d="M 154.5 207.1 L 193.9 188.1" id="9,2"></path><path d="M 174.2 226.1 L 193.9 213.4" id="8,1"></path><path d="M 174.2 226.1 L 193.9 238.8" id="8,0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 193.9 238.8 L 193.9 238.8"></path><path d="M 193.9 213.4 L 193.9 213.4"></path><path d="M 193.9 188.1 L 193.9 188.1"></path><path d="M 193.9 162.7 L 193.9 162.7"></path><path d="M 193.9 137.3 L 193.9 137.3"></path><path d="M 193.9 111.9 L 193.9 111.9"></path><path d="M 193.9 86.6 L 193.9 86.6"></path><path d="M 193.9 61.2 L 193.9 61.2"></path></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:2"><g id="node-0" transform="translate(193.912,238.810)"><circle r="3.5"></circle></g><g id="node-1" transform="translate(193.912,213.436)"><circle r="3.5"></circle></g><g id="node-2" transform="translate(193.912,188.061)"><circle r="3.5"></circle></g><g id="node-3" transform="translate(193.912,162.687)"><circle r="3.5"></circle></g><g id="node-4" transform="translate(193.912,137.313)"><circle r="3.5"></circle></g><g id="node-5" transform="translate(193.912,111.939)"><circle r="3.5"></circle></g><g id="node-6" transform="translate(193.912,86.564)"><circle r="3.5"></circle></g><g id="node-7" transform="translate(193.912,61.190)"><circle r="3.5"></circle></g><g id="node-8" transform="translate(174.215,226.123)"><circle r="3.5"></circle></g><g id="node-9" transform="translate(154.518,207.092)"><circle r="3.5"></circle></g><g id="node-10" transform="translate(134.821,184.890)"><circle r="3.5"></circle></g><g id="node-11" transform="translate(115.124,161.101)"><circle r="3.5"></circle></g><g id="node-12" transform="translate(95.426,136.520)"><circle r="3.5"></circle></g><g id="node-13" transform="translate(75.729,111.542)"><circle r="3.5"></circle></g><g id="node-14" transform="translate(56.032,86.366)"><circle r="3.5"></circle></g></g><g class="toytree-TipLabels" style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11px;font-weight:normal;stroke:none;white-space:pre"><g transform="translate(193.91,238.81)rotate(0)"><text style="" x="15.00" y="2.81">r0</text></g><g trans ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "tbcc04b4783ed48b2b63774e04ee6f680";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {

# %% [markdown]
# ### Modify species tree params to make "variable N" tree

# %%
# set gentime on nodes
ntree = tree.set_node_values(
    feature="Ne", 
    values={i: 100e6 for i in (3,4,5,10,11,12)},
    default=10e6,
)

# draw the tree
ntree.draw(**ts);

# save to file
ntree.write("./trees/n-tree.nwk")
# Out:
# <div class="toyplot" id="t7f2a25669d9a4d7fbae973f6280d3f53" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="te708cfa21bc4454391e01afb7cf2265d" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 300.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t6f08529ffdb441b4bcc7949a5bcaa2f0"><clipPath id="t20da876c0bec452e96d00a199b1481cc"><rect height="240.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t20da876c0bec452e96d00a199b1481cc)"><g class="toytree-mark-Toytree" id="t921c5d2b52ed40fe94620fd35dd8eec2"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 56.0 86.4 L 75.7 111.5" id="14,13" style="stroke-width:2.0"></path><path d="M 75.7 111.5 L 95.4 136.5" id="13,12" style="stroke-width:12.0"></path><path d="M 95.4 136.5 L 115.1 161.1" id="12,11" style="stroke-width:12.0"></path><path d="M 115.1 161.1 L 134.8 184.9" id="11,10" style="stroke-width:12.0"></path><path d="M 134.8 184.9 L 154.5 207.1" id="10,9" style="stroke-width:2.0"></path><path d="M 154.5 207.1 L 174.2 226.1" id="9,8" style="stroke-width:2.0"></path><path d="M 56.0 86.4 L 193.9 61.2" id="14,7" style="stroke-width:2.0"></path><path d="M 75.7 111.5 L 193.9 86.6" id="13,6" style="stroke-width:2.0"></path><path d="M 95.4 136.5 L 193.9 111.9" id="12,5" style="stroke-width:12.0"></path><path d="M 115.1 161.1 L 193.9 137.3" id="11,4" style="stroke-width:12.0"></path><path d="M 134.8 184.9 L 193.9 162.7" id="10,3" style="stroke-width:12.0"></path><path d="M 154.5 207.1 L 193.9 188.1" id="9,2" style="stroke-width:2.0"></path><path d="M 174.2 226.1 L 193.9 213.4" id="8,1" style="stroke-width:2.0"></path><path d="M 174.2 226.1 L 193.9 238.8" id="8,0" style="stroke-width:2.0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 193.9 238.8 L 193.9 238.8"></path><path d="M 193.9 213.4 L 193.9 213.4"></path><path d="M 193.9 188.1 L 193.9 188.1"></path><path d="M 193.9 162.7 L 193.9 162.7"></path><path d="M 193.9 137.3 L 193.9 137.3"></path><path d="M 193.9 111.9 L 193.9 111.9"></path><path d="M 193.9 86.6 L 193.9 86.6"></path><path d="M 193.9 61.2 L 193.9 61.2"></path></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:2"><g id="node-0" transform="translate(193.912,238.810)"><circle r="3.5"></circle></g><g id="node-1" transform="translate(193.912,213.436)"><circle r="3.5"></circle></g><g id="node-2" transform="translate(193.912,188.061)"><circle r="3.5"></circle></g><g id="node-3" transform="translate(193.912,162.687)"><circle r="3.5"></circle></g><g id="node-4" transform="translate(193.912,137.313)"><circle r="3.5"></circle></g><g id="node-5" transform="translate(193.912,111.939)"><circle r="3.5"></circle></g><g id="node-6" transform="translate(193.912,86.564)"><circle r="3.5"></circle></g><g id="node-7" transform="translate(193.912,61.190)"><circle r="3.5"></circle></g><g id="node-8" transform="translate(174.215,226.123)"><circle r="3.5"></circle></g><g id="node-9" transform="translate(154.518,207.092)"><circle r="3.5"></circle></g><g id="node-10" transform="translate(134.821,184.890)"><circle r="3.5"></circle></g><g id="node-11" transform="translate(115.124,161.101)"><circle r="3.5"></circle></g><g id="node-12" transform="translate(95.426,136.520)"><circle r="3.5"></circle></g><g id="node-13" transform="translate(75.729,111.542)"><circle r="3.5"></circle></g> ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "te708cfa21bc4454391e01afb7cf2265d";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)

# %% [markdown]
# ### Simulate a concatenated sequence (chromosome)

# %%
# simulate a long chrom
model = ipcoal.Model(ntree, seed=123)
model.sim_loci(1, 1e6)

# write to db
model.write_loci_to_hdf5(name="n-concat", outdir="db")

# show the total number of genealogies
print('ngenealogies:', model.df.tidx.max())
print('mean len of gtree: {:.2f} bp'.format(model.df.nbps.mean()))

# show the locus (pretty high variation)
model.draw_seqview(0, 0, 50);
# Out:
# wrote 1 loci to /home/deren/gentime-attraction/notebooks/db/n-concat-2.seqs.hdf5
# ngenealogies: 151455
# mean len of gtree: 6.60 bp
# <div class="toyplot" id="t312d5298d03c4bf3b3eaed5c4ed3e085" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="128.0px" id="t646aea0ea4e44339b93c459e1bf60a76" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1020.0 128.0" width="1020.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Table" id="t690caf8c33ad496cb094ed91380633dd"><g transform="translate(127.0,18.543750000000003)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-4.8895" y="2.8104999999999993">r0</text></g><rect height="11.4875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="153.5" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="168.82" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,0%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="184.14" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="199.45999999999998" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,0%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="214.77999999999997" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="230.09999999999997" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="245.41999999999996" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,0%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="260.73999999999995" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,0%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="276.05999999999995" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="291.37999999999994" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="306.69999999999993" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="322.0199999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="337.3399999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="352.6599999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="367.9799999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="383.2999999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="398.6199999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,0%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="413.9399999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="429.2599999999999" y="12.8"></rect><rect height="11.4875" st ...

# %% [markdown]
# ### Confirm concatenation is in the anomaly zone
#
# Here we aim to select a scenario that will lie in the 'anomaly zone', where concatenation will yield incorrect results but a proper MSC method should infer a correct result.

# %%
# init raxml inference
tool = ipa.treeslider(
    data="./db/n-concat.seqs.hdf5",
    name="n-concat",
    scaffold_idxs=0,
    inference_args={
        "f": "d",
        "N": 10,
        "p": 12345,
        "x": None,
        "T": 20,
    }
)
tool.ipcluster['threads'] = 20
tool.show_inference_command()

# infer concat tree
tool.run(auto=True, force=True)
# Out:
# /home/deren/miniconda3/envs/ipy/bin/raxmlHPC-PTHREADS-AVX2 -f d -T 20 -m GTRGAMMA -n ... -w ... -s ... -p 12345 -N 10
# building database: nwindows=1; minsnps=1
# [####################] 100% 0:00:28 | inferring trees
# tree_table written to /home/deren/gentime-attraction/notebooks/analysis-treeslider/n-concat.tree_table.csv

# %%
# re-load the newick from treeslider output
tw = pd.read_csv("./analysis-treeslider/n-concat.tree_table.csv")
etree = toytree.tree(tw.tree[0]).root("r7")

# draw the concat tree
etree.draw(**ts);

# save tree file
etree.write("./trees/n-concat.nwk")
# Out:
# <div class="toyplot" id="tfb75efa0bb8b45bd9165dc318aad9dab" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="ta9bb6627851048638305ff21c96330b9" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 300.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tea3d1d3126464676a957bda94880414c"><clipPath id="t5b3fed323515448aacae47f221b77cb6"><rect height="240.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t5b3fed323515448aacae47f221b77cb6)"><g class="toytree-mark-Toytree" id="tdd4cb660360a4c50a01a14211c8e7505"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 56.0 90.9 L 102.9 120.7" id="14,13"></path><path d="M 102.9 120.7 L 108.4 154.8" id="13,12"></path><path d="M 108.4 154.8 L 113.3 124.6" id="12,11"></path><path d="M 108.4 154.8 L 112.2 184.9" id="12,10"></path><path d="M 112.2 184.9 L 121.1 207.1" id="10,9"></path><path d="M 121.1 207.1 L 135.3 226.1" id="9,8"></path><path d="M 56.0 90.9 L 102.9 61.2" id="14,7"></path><path d="M 102.9 120.7 L 182.1 86.6" id="13,6"></path><path d="M 113.3 124.6 L 191.7 111.9" id="11,5"></path><path d="M 113.3 124.6 L 193.0 137.3" id="11,4"></path><path d="M 112.2 184.9 L 192.7 162.7" id="10,3"></path><path d="M 121.1 207.1 L 192.3 188.1" id="9,2"></path><path d="M 135.3 226.1 L 193.9 213.4" id="8,1"></path><path d="M 135.3 226.1 L 193.9 238.8" id="8,0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 193.9 238.8 L 193.9 238.8"></path><path d="M 193.9 213.4 L 193.9 213.4"></path><path d="M 193.9 188.1 L 192.3 188.1"></path><path d="M 193.9 162.7 L 192.7 162.7"></path><path d="M 193.9 137.3 L 193.0 137.3"></path><path d="M 193.9 111.9 L 191.7 111.9"></path><path d="M 193.9 86.6 L 182.1 86.6"></path><path d="M 193.9 61.2 L 102.9 61.2"></path></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:2"><g id="node-0" transform="translate(193.912,238.810)"><circle r="3.5"></circle></g><g id="node-1" transform="translate(193.867,213.436)"><circle r="3.5"></circle></g><g id="node-2" transform="translate(192.346,188.061)"><circle r="3.5"></circle></g><g id="node-3" transform="translate(192.734,162.687)"><circle r="3.5"></circle></g><g id="node-4" transform="translate(192.951,137.313)"><circle r="3.5"></circle></g><g id="node-5" transform="translate(191.739,111.939)"><circle r="3.5"></circle></g><g id="node-6" transform="translate(182.129,86.564)"><circle r="3.5"></circle></g><g id="node-7" transform="translate(102.890,61.190)"><circle r="3.5"></circle></g><g id="node-8" transform="translate(135.296,226.123)"><circle r="3.5"></circle></g><g id="node-9" transform="translate(121.112,207.092)"><circle r="3.5"></circle></g><g id="node-10" transform="translate(112.167,184.890)"><circle r="3.5"></circle></g><g id="node-11" transform="translate(113.298,124.626)"><circle r="3.5"></circle></g><g id="node-12" transform="translate(108.381,154.758)"><circle r="3.5"></circle></g><g id="node-13" transform="translate(102.890,120.661)"><circle r="3.5"></circle></g><g id="node-14" transform="translate(56.032,90.926)"><circle r="3.5"></circle></g></g><g class="toytree-TipLabels" style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11px;font-weight:normal;stroke:none;white-space:pre"><g transform="translate(193.91,238.81)rotate(0)"><text style="" x="15.00" y="2.81">r0</text></g> ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "ta9bb6627851048638305ff21c96330b9";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {

# %% [markdown]
# ### Simulate unlinked genealogies

# %%
# simulate many unlinked genealogies (same as above)
model = ipcoal.Model(ntree, seed=123)
model.sim_trees(nloci=10000, nsites=1)

# load into a tree object and draw a few
mtre = toytree.mtree(model.df.genealogy)
mtre.draw();

# convert bl units to E(subst.)
for tre in mtre.treelist:
    for node in tre.idx_dict.values():
        node.dist = node.dist * 1e-8      
        
# write re-formatted trees to a tmp file
mtre.write("./trees/n-genealogies.nwk")
# Out:
# <div class="toyplot" id="t1f4fb6b8bae04ba39b92c022d26c6047" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="200.0px" id="tac87a8fa5f29488aac4202a1dbf3e304" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 560.0 200.0" width="560.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="td74fcd6f5dbf402c86f9a09e0b43b579"><clipPath id="t210abec4016a4eb98e13f1add14f0943"><rect height="170.0" width="110.0" x="15.0" y="15.0"></rect></clipPath><g clip-path="url(#t210abec4016a4eb98e13f1add14f0943)"><g class="toytree-mark-Toytree" id="t40e04b1474384468b244bff8dc9323aa"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 26.7 84.9 L 26.7 48.8 L 76.0 48.8" id="14,13"></path><path d="M 26.7 84.9 L 26.7 120.9 L 68.5 120.9" id="14,12"></path><path d="M 76.0 48.8 L 76.0 62.8 L 93.9 62.8" id="13,11"></path><path d="M 68.5 120.9 L 68.5 100.0 L 80.5 100.0" id="12,10"></path><path d="M 68.5 120.9 L 68.5 141.9 L 82.5 141.9" id="12,9"></path><path d="M 82.5 141.9 L 82.5 155.8 L 84.1 155.8" id="9,8"></path><path d="M 76.0 48.8 L 76.0 34.9 L 101.0 34.9" id="13,7"></path><path d="M 93.9 62.8 L 93.9 53.5 L 101.0 53.5" id="11,6"></path><path d="M 93.9 62.8 L 93.9 72.1 L 101.0 72.1" id="11,5"></path><path d="M 80.5 100.0 L 80.5 90.7 L 101.0 90.7" id="10,4"></path><path d="M 80.5 100.0 L 80.5 109.3 L 101.0 109.3" id="10,3"></path><path d="M 82.5 141.9 L 82.5 127.9 L 101.0 127.9" id="9,2"></path><path d="M 84.1 155.8 L 84.1 146.5 L 101.0 146.5" id="8,1"></path><path d="M 84.1 155.8 L 84.1 165.1 L 101.0 165.1" id="8,0"></path></g><g class="toytree-TipLabels" style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9px;font-weight:normal;stroke:none;white-space:pre"><g transform="translate(101.04,165.10)rotate(0)"><text style="" x="10.00" y="2.30">r5</text></g><g transform="translate(101.04,146.50)rotate(0)"><text style="" x="10.00" y="2.30">r4</text></g><g transform="translate(101.04,127.90)rotate(0)"><text style="" x="10.00" y="2.30">r3</text></g><g transform="translate(101.04,109.30)rotate(0)"><text style="" x="10.00" y="2.30">r7</text></g><g transform="translate(101.04,90.70)rotate(0)"><text style="" x="10.00" y="2.30">r6</text></g><g transform="translate(101.04,72.10)rotate(0)"><text style="" x="10.00" y="2.30">r1</text></g><g transform="translate(101.04,53.50)rotate(0)"><text style="" x="10.00" y="2.30">r0</text></g><g transform="translate(101.04,34.90)rotate(0)"><text style="" x="10.00" y="2.30">r2</text></g></g></g></g></g><g class="toyplot-coordinates-Cartesian" id="t8be1064fc0d04c4abf98a69ac6b7894d"><clipPath id="t75f5050dbfa6415bb5a23417a099b900"><rect height="170.0" width="110.0" x="155.0" y="15.0"></rect></clipPath><g clip-path="url(#t75f5050dbfa6415bb5a23417a099b900)"><g class="toytree-mark-Toytree" id="t1e2df0017e534080845147774299af80"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 166.7 88.4 L 166.7 51.2 L 226.9 51.2" id="14,13"></path><path d="M 166.7 88.4 L 166.7 125.6 L 220.2 125.6" id="14,12"></path><path d="M 226.9 51.2 L 226.9 67.4 L 227.2 67.4" id="13,11"></path><path d="M 220.2 125.6 L 220.2 141.9 L 229.8 141.9" id="12,10"></path><path d="M 227.2 67.4 L 227.2 81.4 L 228.8 81.4" id="11,9"></path><path d="M 229.8 141.9 L 229.8 155.8 L 237.4 155.8" id="10,8"></path><path d="M 226.9 51.2 L 226.9 34.9 L 241.0 34.9" id="13,7"></path><path d="M 227.2 67.4 L 227.2 53.5 L 241.0 53.5" id="11,6"></path><path d="M 228.8 81.4 L 228.8 72.1 L 241.0 72.1" id="9,5"></ ...

# %% [markdown]
# ### Confirm ASTRAL-genealogy is not an anomaly

# %%
# infer MSC sptree with ASTRAL
ast = ipa.astral(
    data=[i.write() for i in toytree.mtree("./trees/n-genealogies.nwk")],
    name="n-astral-genealogy",
)
ast.run()

# draw sptree
atree = toytree.tree(ast.tree).root("r7")
atree.draw(**ts);

# save tree file
atree.write("./trees/n-astral-genealogies.nwk")
# Out:
# [astral.5.7.1.jar]
# inferred tree written to (/home/deren/gentime-attraction/notebooks/analysis-astral/n-astral-genealogy.tre)
# <div class="toyplot" id="t93a558728d6b45c0a1704975d2cdcb36" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="tb2bfc915dbb94d058bf035cd46003c4b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 300.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t224af06959be4922bce7567cf6aeed7b"><clipPath id="t0352a9f90ec84d0faec2a899f083e452"><rect height="240.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t0352a9f90ec84d0faec2a899f083e452)"><g class="toytree-mark-Toytree" id="t2d4e43c3affc4b2291e9ee25e0fcec2a"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 56.0 86.4 L 95.3 111.5" id="14,13"></path><path d="M 95.3 111.5 L 96.0 136.5" id="13,12"></path><path d="M 96.0 136.5 L 96.9 161.1" id="12,11"></path><path d="M 96.9 161.1 L 98.0 184.9" id="11,10"></path><path d="M 98.0 184.9 L 106.9 207.1" id="10,9"></path><path d="M 106.9 207.1 L 115.4 226.1" id="9,8"></path><path d="M 56.0 86.4 L 95.3 61.2" id="14,7"></path><path d="M 95.3 111.5 L 173.8 86.6" id="13,6"></path><path d="M 96.0 136.5 L 174.5 111.9" id="12,5"></path><path d="M 96.9 161.1 L 175.5 137.3" id="11,4"></path><path d="M 98.0 184.9 L 176.6 162.7" id="10,3"></path><path d="M 106.9 207.1 L 185.5 188.1" id="9,2"></path><path d="M 115.4 226.1 L 193.9 213.4" id="8,1"></path><path d="M 115.4 226.1 L 193.9 238.8" id="8,0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 193.9 238.8 L 193.9 238.8"></path><path d="M 193.9 213.4 L 193.9 213.4"></path><path d="M 193.9 188.1 L 185.5 188.1"></path><path d="M 193.9 162.7 L 176.6 162.7"></path><path d="M 193.9 137.3 L 175.5 137.3"></path><path d="M 193.9 111.9 L 174.5 111.9"></path><path d="M 193.9 86.6 L 173.8 86.6"></path><path d="M 193.9 61.2 L 95.3 61.2"></path></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:2"><g id="node-0" transform="translate(193.912,238.810)"><circle r="3.5"></circle></g><g id="node-1" transform="translate(193.912,213.436)"><circle r="3.5"></circle></g><g id="node-2" transform="translate(185.470,188.061)"><circle r="3.5"></circle></g><g id="node-3" transform="translate(176.573,162.687)"><circle r="3.5"></circle></g><g id="node-4" transform="translate(175.463,137.313)"><circle r="3.5"></circle></g><g id="node-5" transform="translate(174.501,111.939)"><circle r="3.5"></circle></g><g id="node-6" transform="translate(173.835,86.564)"><circle r="3.5"></circle></g><g id="node-7" transform="translate(95.300,61.190)"><circle r="3.5"></circle></g><g id="node-8" transform="translate(115.377,226.123)"><circle r="3.5"></circle></g><g id="node-9" transform="translate(106.935,207.092)"><circle r="3.5"></circle></g><g id="node-10" transform="translate(98.038,184.890)"><circle r="3.5"></circle></g><g id="node-11" transform="translate(96.928,161.101)"><circle r="3.5"></circle></g><g id="node-12" transform="translate(95.966,136.520)"><circle r="3.5"></circle></g><g id="node-13" transform="translate(95.300,111.542)"><circle r="3.5"></circle></g><g id="node-14" transform="translate(56.032,86.366)"><circle r="3.5"></circle></g></g><g class="toytree-TipLabels" style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11px;font-weight:normal;stroke:none;white-space:pre"><g transform="translate(193.91,238.81)rotate(0)"><text style="" x="15.00" y="2.81">r0</text></g><g transform="trans ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "tb2bfc915dbb94d058bf035cd46003c4b";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {
#                             var amount

# %% [markdown]
# ### Confirm SNAQ-genealogies is not an anomaly

# %%
# infer sptree
snaq0 = ipa.snaq(
    gtrees="./trees/n-genealogies.nwk",
    netin="./trees/n-astral-genealogies.nwk",
    name="n-snaq-genealogies-net0",
    nedges=0,
    nruns=10,
    nproc=10,
    seed=123,
)
snaq0.run()

# infer sptree
snaq1 = ipa.snaq(
    gtrees="./trees/n-genealogies.nwk",
    netin="./trees/n-astral-genealogies.nwk",
    name="n-snaq-genealogies-net1",
    nedges=1,
    nruns=10,
    nproc=10,
    seed=123,
)
snaq1.run()
# Out:
# [SNAQ v.x.y]
# [nproc = 10]
# julia /home/deren/gentime-attraction/notebooks/analysis-snaq/n-snaq-genealogies-net0.jl
# inferred network written to (/home/deren/gentime-attraction/notebooks/analysis-snaq/n-snaq-genealogies-net0.snaq)
# [SNAQ v.x.y]
# [nproc = 10]
# julia /home/deren/gentime-attraction/notebooks/analysis-snaq/n-snaq-genealogies-net1.jl
# inferred network written to (/home/deren/gentime-attraction/notebooks/analysis-snaq/n-snaq-genealogies-net1.snaq)

# %%
snaq1.admix
# Out:
# {'H9': (['r1'], ['r4'], 0.5, {}, '0.01')}

# %%
# draw tree
stree = toytree.tree(snaq1.tree).root("r7")
stree.draw(**ts, admixture_edges=snaq1.admix.values());

# write network
stree.write("trees/n-snaq-genealogies.nwk")
# Out:
# <div class="toyplot" id="te39f9d4547e24f9f91326db464d88a8f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t55da991e348b4ee2b99e90eb07079259" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 300.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tc62eeb2bd19c4f21917c8a68a529e63c"><clipPath id="te00f0af4a3724001b51b8d01976c803f"><rect height="240.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#te00f0af4a3724001b51b8d01976c803f)"><g class="toytree-mark-Toytree" id="t75ac543f68b84dd7a789aa720543a60a"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 56.0 86.4 L 95.1 111.5" id="14,13"></path><path d="M 95.1 111.5 L 95.8 136.5" id="13,12"></path><path d="M 95.8 136.5 L 96.6 161.1" id="12,11"></path><path d="M 96.6 161.1 L 97.9 184.9" id="11,10"></path><path d="M 97.9 184.9 L 107.0 207.1" id="10,9"></path><path d="M 107.0 207.1 L 115.7 226.1" id="9,8"></path><path d="M 56.0 86.4 L 95.1 61.2" id="14,7"></path><path d="M 95.1 111.5 L 173.4 86.6" id="13,6"></path><path d="M 95.8 136.5 L 174.0 111.9" id="12,5"></path><path d="M 96.6 161.1 L 174.8 137.3" id="11,4"></path><path d="M 97.9 184.9 L 176.1 162.7" id="10,3"></path><path d="M 107.0 207.1 L 185.2 188.1" id="9,2"></path><path d="M 115.7 226.1 L 193.9 213.4" id="8,1"></path><path d="M 115.7 226.1 L 193.9 238.8" id="8,0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 193.9 238.8 L 193.9 238.8"></path><path d="M 193.9 213.4 L 193.9 213.4"></path><path d="M 193.9 188.1 L 185.2 188.1"></path><path d="M 193.9 162.7 L 176.1 162.7"></path><path d="M 193.9 137.3 L 174.8 137.3"></path><path d="M 193.9 111.9 L 174.0 111.9"></path><path d="M 193.9 86.6 L 173.4 86.6"></path><path d="M 193.9 61.2 L 95.1 61.2"></path></g><g class="toytree-AdmixEdges" style="fill:none;font-size:14px;stroke:rgba(90.6%,54.1%,76.5%,1.000);stroke-linecap:round;stroke-opacity:0.6;stroke-width:5"><path d="M 193.9 238.8 L 145.3 230.9 L 145.3 146.3 L 96.6 161.1" style="stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:0.7"></path><text style="fill:#262626;fill-opacity:1.0;stroke:none;stroke-opacity:0.7;text-anchor:middle" x="145.26" y="200.61">0.01</text></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:2"><g id="node-0" transform="translate(193.912,238.810)"><circle r="3.5"></circle></g><g id="node-1" transform="translate(193.912,213.436)"><circle r="3.5"></circle></g><g id="node-2" transform="translate(185.214,188.061)"><circle r="3.5"></circle></g><g id="node-3" transform="translate(176.113,162.687)"><circle r="3.5"></circle></g><g id="node-4" transform="translate(174.844,137.313)"><circle r="3.5"></circle></g><g id="node-5" transform="translate(174.022,111.939)"><circle r="3.5"></circle></g><g id="node-6" transform="translate(173.372,86.564)"><circle r="3.5"></circle></g><g id="node-7" transform="translate(95.145,61.190)"><circle r="3.5"></circle></g><g id="node-8" transform="translate(115.686,226.123)"><circle r="3.5"></circle></g><g id="node-9" transform="translate(106.987,207.092)"><circle r="3.5"></circle></g><g id="node-10" transform="translate(97.887,184.890)"><circle r="3.5"></circle></g><g id="node-11" transform="translate(96.618,161.101)"><circle r="3.5"></circle></g><g id="node-12" transform="translate(95.796,136.520)"><circle r="3.5"></circle></g><g id="node-13" transform="translat ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "t55da991e348b4ee2b99e90eb07079259";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }

# %% [markdown]
# ### Simulate loci
# Do 10K loci and test a few range of locus lengths to allow examining length effect.

# %%
# simulate loci that are each 3000bp in length
model = ipcoal.Model(ntree, seed=123)
model.sim_loci(nloci=10000, nsites=2e3)
model.write_loci_to_hdf5(name="n-10000l-2000s", outdir="db")
model.write_snps_to_hdf5(name="n-10000l-2000s", outdir="db")

# draw seqview
model.draw_seqview(0, 0, 50);
# Out:
# wrote 10000 loci to /home/deren/gentime-attraction/notebooks/db/n-10000l-2000s.seqs.hdf5
# wrote 17611826 SNPs to /home/deren/gentime-attraction/notebooks/db/n-10000l-2000s.snps.hdf5
# <div class="toyplot" id="tf0195709a2ce4e38a8f392003e07c73f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="128.0px" id="tda87c5628cf440e4b20ececd963341d0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 1020.0 128.0" width="1020.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Table" id="tc719d7a134e9470f932da8e20b4f4273"><g transform="translate(127.0,18.543750000000003)"><text style="fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:helvetica;font-size:11.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-4.8895" y="2.8104999999999993">r0</text></g><rect height="11.4875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="153.5" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="168.82" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="184.14" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="199.45999999999998" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="214.77999999999997" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="230.09999999999997" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="245.41999999999996" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="260.73999999999995" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="276.05999999999995" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="291.37999999999994" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="306.69999999999993" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,0%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="322.0199999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="337.3399999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,0%,100%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="352.6599999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="367.9799999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="383.2999999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(100%,0%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="398.6199999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="413.9399999999999" y="12.8"></rect><rect height="11.4875" style="fill:rgb(0%,50.2%,0%);fill-opacity:1.0;opacity:0.5;stroke:none" width="13.819999999999993" x="429.2599999999999" y="12.8"></rect><rect height="11.4875" style="fi ...

# %% [markdown]
# ### Infer gene trees from loci

# %%
# init tree slider inference tool
tool = ipa.treeslider(
    data="./db/n-10000l-2000s.seqs.hdf5",
    name="n-10000l-2000s",
    scaffold_idxs=range(10000),
    inference_args={
        "N": 10,
        "f": "d",
        "p": 12345,
        "x": None,
        "T": 2,
    }
)

# infer all gene trees
tool.ipcluster['cores'] = 20
tool.ipcluster['threads'] = 2
tool.run(auto=True, force=True)
# Out:
# building database: nwindows=10000; minsnps=1
# [####################] 100% 1:52:00 | inferring trees
# tree_table written to /home/deren/gentime-attraction/notebooks/analysis-treeslider/n-10000l-2000s.tree_table.csv

# %%
# load tree slider (gene tree inference) results
tw = pd.read_csv("./analysis-treeslider/n-10000l-2000s.tree_table.csv", index_col=0)

# load gene trees into toytree multitree object
mtre = toytree.mtree(tw.tree)
mtre.treelist = [i.root("r7") for i in mtre.treelist]
mtre.draw(ts='o', use_edge_lengths=False);

# write list of trees as a tmp file
print(len(mtre), "gene trees")
mtre.write("./trees/n-genetrees.nwk")
# Out:
# 10000 gene trees
# <div class="toyplot" id="t413a861b56ab41f6bede6a96a9738bfc" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="200.0px" id="t6aa4f157858e475785ae015536d2fbac" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 560.0 200.0" width="560.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t411a0d5a1d0e487197467f1b0bf4f216"><clipPath id="te483ec0381e940a59f84b55797cc30ea"><rect height="170.0" width="110.0" x="15.0" y="15.0"></rect></clipPath><g clip-path="url(#te483ec0381e940a59f84b55797cc30ea)"><g class="toytree-mark-Toytree" id="t15a2727c2fd84f1d8c35dbc4692602ce"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 31.3 56.7 L 43.0 78.5" id="14,13"></path><path d="M 43.0 78.5 L 54.8 103.5" id="13,12"></path><path d="M 54.8 103.5 L 90.0 81.4" id="12,11"></path><path d="M 54.8 103.5 L 66.5 125.6" id="12,10"></path><path d="M 66.5 125.6 L 78.3 141.9" id="10,9"></path><path d="M 78.3 141.9 L 90.0 155.8" id="9,8"></path><path d="M 31.3 56.7 L 101.8 34.9" id="14,7"></path><path d="M 43.0 78.5 L 101.8 53.5" id="13,6"></path><path d="M 90.0 81.4 L 101.8 72.1" id="11,5"></path><path d="M 90.0 81.4 L 101.8 90.7" id="11,4"></path><path d="M 66.5 125.6 L 101.8 109.3" id="10,3"></path><path d="M 78.3 141.9 L 101.8 127.9" id="9,2"></path><path d="M 90.0 155.8 L 101.8 146.5" id="8,1"></path><path d="M 90.0 155.8 L 101.8 165.1" id="8,0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 101.8 165.1 L 101.8 165.1"></path><path d="M 101.8 146.5 L 101.8 146.5"></path><path d="M 101.8 127.9 L 101.8 127.9"></path><path d="M 101.8 109.3 L 101.8 109.3"></path><path d="M 101.8 90.7 L 101.8 90.7"></path><path d="M 101.8 72.1 L 101.8 72.1"></path><path d="M 101.8 53.5 L 101.8 53.5"></path><path d="M 101.8 34.9 L 101.8 34.9"></path></g><g class="toytree-Nodes" style="fill:rgb(10.6%,62%,46.7%);fill-opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.5"><g id="node-0" transform="translate(101.768,165.104)"><circle r="4.0"></circle></g><g id="node-1" transform="translate(101.768,146.503)"><circle r="4.0"></circle></g><g id="node-2" transform="translate(101.768,127.902)"><circle r="4.0"></circle></g><g id="node-3" transform="translate(101.768,109.301)"><circle r="4.0"></circle></g><g id="node-4" transform="translate(101.768,90.699)"><circle r="4.0"></circle></g><g id="node-5" transform="translate(101.768,72.098)"><circle r="4.0"></circle></g><g id="node-6" transform="translate(101.768,53.497)"><circle r="4.0"></circle></g><g id="node-7" transform="translate(101.768,34.896)"><circle r="4.0"></circle></g><g id="node-8" transform="translate(90.018,155.804)"><circle r="4.0"></circle></g><g id="node-9" transform="translate(78.268,141.853)"><circle r="4.0"></circle></g><g id="node-10" transform="translate(66.518,125.577)"><circle r="4.0"></circle></g><g id="node-11" transform="translate(90.018,81.399)"><circle r="4.0"></circle></g><g id="node-12" transform="translate(54.767,103.488)"><circle r="4.0"></circle></g><g id="node-13" transform="translate(43.017,78.492)"><circle r="4.0"></circle></g><g id="node-14" transform="translate(31.267,56.694)"><circle r="4.0"></circle></g></g><g class="toytree-TipLabels" style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9px;font-weight:normal;stroke:none;white-space:pre"><g transform="translate(101.77,165.10)rotate(0)"><text style="" x="10.00" y="2.30">r0</text></g><g transform="translate(101.77,14 ...

# %% [markdown]
# ### Infer SNAQ network from inferred gene trees

# %%
snaq0 = ipa.snaq(
    gtrees="./trees/n-genetrees.nwk",
    netin="./trees/n-astral-genealogies.nwk",
    name="n-genetrees-net0",
    nedges=0,
    nruns=10,
    nproc=10,
)
snaq0.run()

snaq1 = ipa.snaq(
    gtrees="./trees/n-genetrees.nwk",
    netin="./trees/n-astral-genealogies.nwk",
    name="n-genetrees-net1",
    nedges=1,
    nruns=10,
    nproc=10,
)
snaq1.run()
# Out:
# using existing CF table: /home/deren/gentime-attraction/notebooks/analysis-snaq/n-genetrees-net1.CFs.csv
# [SNAQ v.x.y]
# [nproc = 10]
# julia /home/deren/gentime-attraction/notebooks/analysis-snaq/n-genetrees-net1.jl
# inferred network written to (/home/deren/gentime-attraction/notebooks/analysis-snaq/n-genetrees-net1.snaq)

# %%
snaq1.admix
# Out:
# {'H9': (['r2'], ['r1'], 0.5, {}, '0.277')}

# %%
# draw tree
stree = toytree.tree(snaq1.tree).root("r7")
stree.draw(**ts, admixture_edges=snaq1.admix.values());

# save tree
stree.write("./trees/n-snaq-genetrees.nwk")
# Out:
# <div class="toyplot" id="t3552b5eb3c6c4d83a379efb7f240be2e" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t33dde33611dc4cc5a4b91314a166143b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 300.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="ta639b64f52db4851b503be2f455d2e99"><clipPath id="t1d8d2e9bf5004a6384ff5146d5997a4d"><rect height="240.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t1d8d2e9bf5004a6384ff5146d5997a4d)"><g class="toytree-mark-Toytree" id="tcf37106e44264de8802821a434e02365"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 56.0 86.4 L 76.5 111.5" id="14,13"></path><path d="M 76.5 111.5 L 78.7 136.5" id="13,12"></path><path d="M 78.7 136.5 L 80.8 161.1" id="12,11"></path><path d="M 80.8 161.1 L 84.0 184.9" id="11,10"></path><path d="M 84.0 184.9 L 112.7 207.1" id="10,9"></path><path d="M 112.7 207.1 L 152.9 226.1" id="9,8"></path><path d="M 56.0 86.4 L 76.5 61.2" id="14,7"></path><path d="M 76.5 111.5 L 117.5 86.6" id="13,6"></path><path d="M 78.7 136.5 L 119.7 111.9" id="12,5"></path><path d="M 80.8 161.1 L 121.8 137.3" id="11,4"></path><path d="M 84.0 184.9 L 125.0 162.7" id="10,3"></path><path d="M 112.7 207.1 L 153.7 188.1" id="9,2"></path><path d="M 152.9 226.1 L 193.9 213.4" id="8,1"></path><path d="M 152.9 226.1 L 193.9 238.8" id="8,0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 193.9 238.8 L 193.9 238.8"></path><path d="M 193.9 213.4 L 193.9 213.4"></path><path d="M 193.9 188.1 L 153.7 188.1"></path><path d="M 193.9 162.7 L 125.0 162.7"></path><path d="M 193.9 137.3 L 121.8 137.3"></path><path d="M 193.9 111.9 L 119.7 111.9"></path><path d="M 193.9 86.6 L 117.5 86.6"></path><path d="M 193.9 61.2 L 76.5 61.2"></path></g><g class="toytree-AdmixEdges" style="fill:none;font-size:14px;stroke:rgba(90.6%,54.1%,76.5%,1.000);stroke-linecap:round;stroke-opacity:0.6;stroke-width:5"><path d="M 153.7 188.1 L 153.3 188.2 L 153.3 226.2 L 152.9 226.1" style="stroke:rgb(98.8%,55.3%,38.4%);stroke-opacity:0.7"></path><text style="fill:#262626;fill-opacity:1.0;stroke:none;stroke-opacity:0.7;text-anchor:middle" x="153.30" y="219.24">0.277</text></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:2"><g id="node-0" transform="translate(193.912,238.810)"><circle r="3.5"></circle></g><g id="node-1" transform="translate(193.912,213.436)"><circle r="3.5"></circle></g><g id="node-2" transform="translate(153.690,188.061)"><circle r="3.5"></circle></g><g id="node-3" transform="translate(125.041,162.687)"><circle r="3.5"></circle></g><g id="node-4" transform="translate(121.783,137.313)"><circle r="3.5"></circle></g><g id="node-5" transform="translate(119.693,111.939)"><circle r="3.5"></circle></g><g id="node-6" transform="translate(117.546,86.564)"><circle r="3.5"></circle></g><g id="node-7" transform="translate(76.537,61.190)"><circle r="3.5"></circle></g><g id="node-8" transform="translate(152.903,226.123)"><circle r="3.5"></circle></g><g id="node-9" transform="translate(112.682,207.092)"><circle r="3.5"></circle></g><g id="node-10" transform="translate(84.032,184.890)"><circle r="3.5"></circle></g><g id="node-11" transform="translate(80.775,161.101)"><circle r="3.5"></circle></g><g id="node-12" transform="translate(78.685,136.520)"><circle r="3.5"></circle></g><g id="node-13" transform="transl ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "t33dde33611dc4cc5a4b91314a166143b";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function

# %% [markdown]
# ### Infer ASTRAL tree from inferred gene trees

# %%
# infer MSC sptree with ASTRAL
ast = ipa.astral(
    data=[i.write() for i in toytree.mtree("./trees/n-genetrees.nwk")],
    name="n-astral-genetrees",
)
ast.run()

# draw sptree
atree = toytree.tree(ast.tree).root("r7")
atree.draw(**ts);

# save tree file
atree.write("./trees/n-astral-genetrees.nwk")
# Out:
# [astral.5.7.1.jar]
# inferred tree written to (/home/deren/gentime-attraction/notebooks/analysis-astral/n-astral-genetrees.tre)
# <div class="toyplot" id="ta4ed9efb32e54d68bb8dd20e46490c1f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="300.0px" id="t8f35e393e25e45519e09d9d376f487da" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 260.0 300.0" width="260.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="tb4a74e7aa8d84815bc3bd82457397278"><clipPath id="tb72e2c3320894893ae61026b89df6dae"><rect height="240.0" width="200.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#tb72e2c3320894893ae61026b89df6dae)"><g class="toytree-mark-Toytree" id="t75ab7706048b430fa98d353bc7d6a3af"><g class="toytree-Edges" style="fill:none;stroke:rgb(14.9%,14.9%,14.9%);stroke-linecap:round;stroke-opacity:1;stroke-width:2"><path d="M 56.0 86.4 L 56.0 111.5" id="14,13"></path><path d="M 56.0 111.5 L 58.7 136.5" id="13,12"></path><path d="M 58.7 136.5 L 61.3 161.1" id="12,11"></path><path d="M 61.3 161.1 L 65.2 184.9" id="11,10"></path><path d="M 65.2 184.9 L 110.7 207.1" id="10,9"></path><path d="M 110.7 207.1 L 141.8 226.1" id="9,8"></path><path d="M 56.0 86.4 L 108.2 61.2" id="14,7"></path><path d="M 56.0 111.5 L 108.2 86.6" id="13,6"></path><path d="M 58.7 136.5 L 110.8 111.9" id="12,5"></path><path d="M 61.3 161.1 L 113.4 137.3" id="11,4"></path><path d="M 65.2 184.9 L 117.3 162.7" id="10,3"></path><path d="M 110.7 207.1 L 162.8 188.1" id="9,2"></path><path d="M 141.8 226.1 L 193.9 213.4" id="8,1"></path><path d="M 141.8 226.1 L 193.9 238.8" id="8,0"></path></g><g class="toytree-AlignEdges" style="stroke:rgb(66.3%,66.3%,66.3%);stroke-dasharray:2, 4;stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"><path d="M 193.9 238.8 L 193.9 238.8"></path><path d="M 193.9 213.4 L 193.9 213.4"></path><path d="M 193.9 188.1 L 162.8 188.1"></path><path d="M 193.9 162.7 L 117.3 162.7"></path><path d="M 193.9 137.3 L 113.4 137.3"></path><path d="M 193.9 111.9 L 110.8 111.9"></path><path d="M 193.9 86.6 L 108.2 86.6"></path><path d="M 193.9 61.2 L 108.2 61.2"></path></g><g class="toytree-Nodes" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;stroke:rgb(0%,0%,0%);stroke-opacity:1.0;stroke-width:2"><g id="node-0" transform="translate(193.912,238.810)"><circle r="3.5"></circle></g><g id="node-1" transform="translate(193.912,213.436)"><circle r="3.5"></circle></g><g id="node-2" transform="translate(162.841,188.061)"><circle r="3.5"></circle></g><g id="node-3" transform="translate(117.339,162.687)"><circle r="3.5"></circle></g><g id="node-4" transform="translate(113.382,137.313)"><circle r="3.5"></circle></g><g id="node-5" transform="translate(110.850,111.939)"><circle r="3.5"></circle></g><g id="node-6" transform="translate(108.150,86.564)"><circle r="3.5"></circle></g><g id="node-7" transform="translate(108.150,61.190)"><circle r="3.5"></circle></g><g id="node-8" transform="translate(141.794,226.123)"><circle r="3.5"></circle></g><g id="node-9" transform="translate(110.723,207.092)"><circle r="3.5"></circle></g><g id="node-10" transform="translate(65.221,184.890)"><circle r="3.5"></circle></g><g id="node-11" transform="translate(61.264,161.101)"><circle r="3.5"></circle></g><g id="node-12" transform="translate(58.732,136.520)"><circle r="3.5"></circle></g><g id="node-13" transform="translate(56.032,111.542)"><circle r="3.5"></circle></g><g id="node-14" transform="translate(56.032,86.366)"><circle r="3.5"></circle></g></g><g class="toytree-TipLabels" style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:11px;font-weight:normal;stroke:none;white-space:pre"><g transform="translate(193.91,238.81)rotate(0)"><text style="" x="15.00" y="2.81">r0</text></g><g transform="tr ...
# {
# var modules={};
# modules["toyplot/canvas/id"] = "t8f35e393e25e45519e09d9d376f487da";
# modules["toyplot/canvas"] = (function(canvas_id)
#     {
#         return document.querySelector("#" + canvas_id);
#     })(modules["toyplot/canvas/id"]);
# modules["toyplot.coordinates.Axis"] = (
#         function(canvas)
#         {
#             function sign(x)
#             {
#                 return x < 0 ? -1 : x > 0 ? 1 : 0;
#             }
#
#             function mix(a, b, amount)
#             {
#                 return ((1.0 - amount) * a) + (amount * b);
#             }
#
#             function log(x, base)
#             {
#                 return Math.log(Math.abs(x)) / Math.log(base);
#             }
#
#             function in_range(a, x, b)
#             {
#                 var left = Math.min(a, b);
#                 var right = Math.max(a, b);
#                 return left <= x && x <= right;
#             }
#
#             function inside(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.min, range, segment.range.max))
#                         return true;
#                 }
#                 return false;
#             }
#
#             function to_domain(range, projection)
#             {
#                 for(var i = 0; i != projection.length; ++i)
#                 {
#                     var segment = projection[i];
#                     if(in_range(segment.range.bounds.min, range, segment.range.bounds.max))
#                     {
#                         if(segment.scale == "linear")
#                         {
#                             var amount = (rang
